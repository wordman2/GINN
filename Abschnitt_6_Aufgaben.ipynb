# %% [markdown]
# <a href="https://colab.research.google.com/github/wordman2/GINN/blob/main/Abschnitt_6_Aufgaben.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GINN Teil 6

# %% [markdown]
# Sigmoid und Ableitung
#
# $
#  sig\left( x \right) = \frac{1}{{1 + e^x }} \\
#  sig'\left( x \right) = sig\left( x \right) \cdot \left( {1 - sig\left( x \right)} \right) \\
#  $

# %% [markdown]
# ## 1.&nbsp;Kette von Lineartransformationen
#
#
#
# *  Gegeben sei ein neuronales Netz, das einen Wert durch eine Kette von n Lineartransformationen mit Bias und anschließender Sigmoid-Aktivierungsfunktion transformiert (also ein Neuron pro Hidden Layer). Der Eingabewert sei 0.5, alle Biases seien -0.5 und alle Gewichte seien anfangs auf 1 gesetzt. Wie hoch ist der Gradient an jeder Stelle in der Kette in Abhängigkeit von der Länge der Kette n? Stellen Sie hierzu zunächst mathematische Überlegungen mit Stift und Papier an. Anschließend können Sie mit Python oder beliebigen anderen Tools eine aussagekräftige Visualisierung hierzu erzeugen.

# %% [markdown]
# ## 2.&nbsp;Einschichtiges Perzeptron
#
# *   Bestimmen Sie die Parameter eines einschichtigen Perzeptrons mit Stufenfunktion als Aktivierung, das aktiviert werden soll wenn die Mehrheit der binären Eingabewerte = 1 ist.
# *   Definieren Sie eine lineare Regression als Perzeptron

# %% [markdown]
# ## 3.&nbsp;Mehrschichtiges Perzeptron
#
# In dieser Übung betrachten wir ein lineares Multilayer-Perzeptron, wie die unten dargestellten (MLP1 und MLP2). In einem linearen MLP hat jede Einheit eine lineare Aktivierungsfunktion, wie die Identitätsfunktion $ g: \mathbb{R} \rightarrow \mathbb{R}, g(x) = x $. Für einen Vektor $x \in \mathbb{R}^2, x = (x_1, x_2)^T $, und die Identität als Aktivierungsfunktion, ist der Ausgang von MLP1, $ \sigma' $, gleich:
# $
# \sigma' = w^T x = w_1 x_1 + w_2 x_2.
# $
#
# *   Beweisen Sie, dass für beliebige $a, b, c, d, e, f \in \mathbb{R} $ in MLP2
# immer $ w_1, w_2 \in \mathbb{R} $ in MLP1 existieren, so dass die beiden Ausgänge, $ o' $ und $ o'' $, gleich sind.
# *   Betrachten Sie $ x = (x_1, x_2) $, wobei $ x_1, x_2 \in \{0, 1\} $, beweisen Sie, dass ein lineares MLP nicht die XOR-Funktion seiner Eingabe lernen kann. Hinweis:  XOR[$x_1, x_2$]  ist gleich 1, wenn  $ x_1 \neq x_2  $ und 0 andernfalls.
#
# ![image.png](data:image/png;base64,...)
